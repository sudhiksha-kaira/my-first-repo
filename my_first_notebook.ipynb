# %% [markdown]
# Hardware - refers to the physical, tangible components of a computer system. eg: CPU, monitor
# Software - refers set of intangible instructions,programs that tell the hardware what to do. eg: Windows, apps
